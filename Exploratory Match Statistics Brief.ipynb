# %%
# Things I want to Observe:

# (It might make sense to do this by player, so, if you type into the
# python prompt the initials of the player you want to observe, it will
# output the following statistics below)

# I think it also makes sense to separate each section, and then once 
# each section is done, bring them together into one deliverable piece
# of code that is runnable from the command prompt.

# Serve Information:
    # By Side
        # For First Serve
            # Directions
                # Frequencies
                # Accuracy
        # For Second Serve
            # Directions
                # Frequencies
                # Accuracy
    # Miscellaneous Serve Data:
        # Service Points Won:
            # First Serve (Total)
            # Second Serve (Total)
            # By Direction on First Serve
            # By Direction on Second Serve
        # Serve Volley Frequency (by Side)
            # Serve & Volley Efficiency (% of times SV/% of times SV won point)
    # Direction on Big Points:
        # First Serve:
            # 0-0
            # 30-30
            # 30-40
            # Duece
        # Second Serve
            # 0-0
            # 30-30
            # 30-40
            # Duece

# Return Information:
    # By Side:
        # Return Error Rate
            # Vs First Serve (Side) (Serve Type: Wide, Body, Tee)
            # Vs Second Serve (Side) (Serve Type: Wide, Body, Tee)
        # Return Depth vs Serve (Wide, Body, Tee)
            # By Stroke:
                # Forehand
                # Backhand
        # Return Type by serve:
            # Vs First Serve (Side) (Serve Type: Wide, Body, Tee)
            # Vs Second Serve (Side) (Serve Type: Wide, Body, Tee)

# Rally information:
    # Rally Length
        # On Serve:
            # AVG Rally length on Serve (First and Second Serve)
            # % of Points won at following Rally Lengths:
                # 0-4
                # 5-8
                # 9+
            # Unforced Errors:
                # By Stroke
                    # By First and Second Serve
            # Winners or Forced Errors:
                # By Stroke
                    # By First and Second Serve
        # On return
            # AVG Rally length on Return (First and Second Serve)
            # % of Points won at following Rally Lengths:
                # 0-4
                # 5-8
                # 9+
            # Unforced Errors:
                # By Stroke
                    # By First and Second Serve
            # Winners or Forced Errors:
                # By Stroke
                    # By First and Second Serve
    # Miscellaneous Rally Information:
        # As Server:
            # % of Rallies approached net
                # On First Serve
                # On Second Serve
            # Drop Shot Frequency (% of Points where a Drop Shot was Played)
                # Drop Shot Win %
        # As Returner:
            # % of Rallies approached net
                # On First Serve
                # On Second Serve            
            # Drop Shot Frequency (% of Points where a Drop Shot was Played)
                # Drop Shot Win %

# %%
# Deliverables I would Like:
    # Excel
        # You should be able to input the Initials of the player
        # that you'd like to observe at the command line, along
        # with the name of the excel sheet, in order to get all
        # information you would like
    # Compatible with Current Match Charting Format
        # This means:
            # I'm going to have to add the Side Column (Duece/Ad), in Excel
            # I'm probably going to need a formatting function

# %%
# Preprocessing Steps:
    # Adding Duece and Ad Side without Creating a New CSV
    # "Tokenizing" Data without Creating a New CSV
    # Eliminating All Tiebreak Data
